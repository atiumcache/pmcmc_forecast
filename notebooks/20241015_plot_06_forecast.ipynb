# %%
from src.utils.plotting import plot_predictions_with_quantile_range
import warnings
import pandas as pd

warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=pd.errors.SettingWithCopyWarning)

# %%
plot_predictions_with_quantile_range("2023-11-04", "06", weeks_prior=8)

# %%
plot_predictions_with_quantile_range("2023-12-02", "06", weeks_prior=8)

# %%
plot_predictions_with_quantile_range("2023-12-09", "06", weeks_prior=8)

# %%
plot_predictions_with_quantile_range("2024-01-06", "06", weeks_prior=8)

# %%
plot_predictions_with_quantile_range("2024-02-24", "06", weeks_prior=8)

# %%
plot_predictions_with_quantile_range("2024-03-30", "06", weeks_prior=8)
