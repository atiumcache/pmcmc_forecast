# 97  0.085720  0.095983  0.094074  0.097059  0.093789  0.109216
# 98  0.081269  0.078955  0.088369  0.084986  0.082059  0.112322
# 99  0.084363  0.086005  0.089415  0.088900  0.086859  0.098678
#
# [100 rows x 308 columns]

# %%
# Average the 100 rows
row_means = df.mean(axis=0)

# Transpose the DataFrame
transposed_df = row_means.to_frame()

transposed_df
# Out:
#             0
# 0    0.180160
# 1    0.180515
# 2    0.176521
# 3    0.174910
# 4    0.167201
# ..        ...
# 303  0.106357
# 304  0.103020
# 305  0.102871
# 306  0.102562
# 307  0.108156
#
# [308 rows x 1 columns]

# %%
num_rows = len(transposed_df)
end_date = pd.to_datetime("2024-04-27")
date_range = pd.date_range(end=end_date, periods=num_rows)
transposed_df["date"] = date_range

# %%
transposed_df.rename({0: "beta"}, axis="columns", inplace=True)

# %%
transposed_df
# Out:
#          beta       date
# 0    0.180160 2023-06-25
# 1    0.180515 2023-06-26
# 2    0.176521 2023-06-27
# 3    0.174910 2023-06-28
# 4    0.167201 2023-06-29
# ..        ...        ...
# 303  0.106357 2024-04-23
# 304  0.103020 2024-04-24
# 305  0.102871 2024-04-25
# 306  0.102562 2024-04-26
# 307  0.108156 2024-04-27
#
# [308 rows x 2 columns]

# %%
target_dates = pd.read_csv("../datasets/target_dates.csv")
target_dates
# Out:
#           date
# 0   2023-10-14
# 1   2023-10-21
# 2   2023-10-28
# 3   2023-11-04
# 4   2023-11-11
# 5   2023-11-18
# 6   2023-11-25
# 7   2023-12-02
# 8   2023-12-09
# 9   2023-12-16
# 10  2023-12-23
# 11  2023-12-30
# 12  2024-01-06
# 13  2024-01-13
# 14  2024-01-20
# 15  2024-01-27
# 16  2024-02-03
# 17  2024-02-10
# 18  2024-02-17
# 19  2024-02-24
# 20  2024-03-02
# 21  2024-03-09
# 22  2024-03-16
# 23  2024-03-23
# 24  2024-03-30
# 25  2024-04-06
# 26  2024-04-13

# %%
from os import path
from src import paths
import os

df = transposed_df

for target_date in target_dates["date"]:
    start_date = pd.to_datetime(target_date) - pd.Timedelta(days=50)
    filtered_df = df[(df["date"] > start_date) & (df["date"] <= target_date)]
    filtered_df.insert(0, "time_0", range(len(filtered_df)))
    filtered_df = filtered_df.drop(columns=["date"])
    file_path = path.join(paths.PF_OUTPUT_DIR, target_date, "04.csv")
    os.makedirs(path.dirname(file_path), exist_ok=True)
    filtered_df.to_csv(file_path, index=False)
