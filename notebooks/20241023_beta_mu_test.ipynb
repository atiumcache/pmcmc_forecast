# %%
from src.pmcmc.main import main as pmcmc_main

pmcmc_main(location_code="06", target_date="2023-12-01")
# Out:
# [0.01, 0.3]
# 0.01
# ...
# Running Particle Filter:   0%|          | 0/160 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from src.pmcmc.main import main as pmcmc_main
# ----> 3 pmcmc_main(location_code="06", target_date="2023-12-01")
#
# File ~/PycharmProjects/pmcmc_forecast/src/pmcmc/main.py:65, in main(location_code, target_date)
#      54 prior = get_prior(min_val=prior_range[0], max_val=prior_range[1])
#      56 pmcmc_algo = PMCMC(
#      57     iterations=config["mcmc"]["iterations"],
#      58     init_thetas=config["mcmc"]["initial_theta"],
#    (...)
#      63     file_label=config["mcmc"]["file_label"],
#      64 )
# ---> 65 pmcmc_algo.run()
#      67 pmcmc_algo.output_data()
#      69 return pmcmc_algo.mle_betas
#
# File ~/PycharmProjects/pmcmc_forecast/src/pmcmc/pmcmc.py:113, in PMCMC.run(self)
# ...

# %%
from src.utils.plotting import plot_mcmc_overview
from src.utils import paths
import os


dec_01_path = os.path.join(paths.OUTPUT_DIR, "beta_mu_test_20241029", "2023-12-01.json")
jan_30_path = os.path.join(paths.OUTPUT_DIR, "beta_mu_test_20241029", "2024-01-30.json")
plot_mcmc_overview(dec_01_path)
# Out:
# Chain 1: 0.912 acceptance rate.

# %%
plot_mcmc_overview(jan_30_path)
# Out:
# Chain 1: 0.922 acceptance rate.
